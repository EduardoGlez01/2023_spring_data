# %% [markdown]
# # Visual Exploration
#
# #### You have a <a href = "https://docs.google.com/spreadsheets/d/1CYdbCfj0aF-bKNJ3lIPe6_rKkWT-IlCMXxNQtjkiD34/edit?usp=sharing">spreadsheet</a> that has the price of monthly cable bills, median income, and social security percentage increases. The data is from 1995 to 2022.
#
# #### Create a line chart that hopefully reveals a trend between cable prices, median income and social security increases. Make the cable bill red; median income blue, and social security gray.
#
# #### What would be your "thesis" based on your findings?
#
# **Note about social security increases:**
#
# Each year the U.S. government increases the amount of social security retired people receive. That increase is based on the annual inflation rate  and the political climate (or party in control). I have indexed the numbers so 1995 is 100, and each year after that the number reflects a percentage increase since 1995. So between 1995 at 100 and 1996 at 102.6 reflects a 2.6 percent increase. And between 1995 and 1997 reflects a 5.6 percent increase.

# %%
import pandas as pd

# %%
df = pd.read_csv("cable-bill-only.csv")
df
# Out:
#     Year  Avg. cable bill Median household income  \
# 0   1995            22.35                  35,249
# 1   1996            23.28                  36,689
# 2   1997            26.31                  38,229
# 3   1998            27.88                  40,148
# 4   1999            28.94                  41,994
# 5   2000            31.22                  42,349
# 6   2001            33.75                  42,710
# 7   2002            36.47                  43,057
# 8   2003            38.95                  43,564
# 9   2004            41.04                  44,684
# 10  2005            43.04                  46,242
# 11  2006            43.26                  48,451
# 12  2007            47.27                  50,740
# 13  2008            49.65                  52,029
# 14  2009            52.37                  50,221
# 15  2010            54.44                  50,046
# 16  2011            57.46                  50,502
# 17  2012            61.63                  51,371
# 18  2013            69.18                  52,250
# 19  2014            71.45                  53,657
# 20  2015            78.42                  55,775
# 21  2016           150.98                  57,617
# 22  2017           168.49                  61,372
# 23  2018           199.99                  64,324
# 24  2019           210.84                  69,560
# 25  2020           217.42                  67,521
# 26  2021           231.10                  70,784
# 27  2022           251.48                  78,075
#
#     Social Security cost-of-living adjustment
# 0                                       100.0
# 1                                       102.6
# 2                                       105.6
# 3                                       107.8
# 4                                       109.2
# 5                                       111.9
# 6                                       115.8
# 7                                       118.9
# 8                                       120.5
# 9                                       123.0
# 10                                      126.4
# 11                                      131.6
# 12                                      135.9
# 13                                      139.0
# 14                                      147.1
# 15                                      147.1
# 16                                      147.1
# 17                                      152.4
# 18                                      155.0
# 19                                      157.3
# 20                                      159.0
# 21                                      159.0
# 22                                      159.3
# 23                                      161.3
# 24                                      164.1
# 25                                      165.7
# 26                                      167.0
# 27                                      172.9

# %%
df["Median household income"]= df["Median household income"].str.replace(',', '.')
df
# Out:
#     Year  Avg. cable bill Median household income  \
# 0   1995            22.35                  35.249
# 1   1996            23.28                  36.689
# 2   1997            26.31                  38.229
# 3   1998            27.88                  40.148
# 4   1999            28.94                  41.994
# 5   2000            31.22                  42.349
# 6   2001            33.75                  42.710
# 7   2002            36.47                  43.057
# 8   2003            38.95                  43.564
# 9   2004            41.04                  44.684
# 10  2005            43.04                  46.242
# 11  2006            43.26                  48.451
# 12  2007            47.27                  50.740
# 13  2008            49.65                  52.029
# 14  2009            52.37                  50.221
# 15  2010            54.44                  50.046
# 16  2011            57.46                  50.502
# 17  2012            61.63                  51.371
# 18  2013            69.18                  52.250
# 19  2014            71.45                  53.657
# 20  2015            78.42                  55.775
# 21  2016           150.98                  57.617
# 22  2017           168.49                  61.372
# 23  2018           199.99                  64.324
# 24  2019           210.84                  69.560
# 25  2020           217.42                  67.521
# 26  2021           231.10                  70.784
# 27  2022           251.48                  78.075
#
#     Social Security cost-of-living adjustment
# 0                                       100.0
# 1                                       102.6
# 2                                       105.6
# 3                                       107.8
# 4                                       109.2
# 5                                       111.9
# 6                                       115.8
# 7                                       118.9
# 8                                       120.5
# 9                                       123.0
# 10                                      126.4
# 11                                      131.6
# 12                                      135.9
# 13                                      139.0
# 14                                      147.1
# 15                                      147.1
# 16                                      147.1
# 17                                      152.4
# 18                                      155.0
# 19                                      157.3
# 20                                      159.0
# 21                                      159.0
# 22                                      159.3
# 23                                      161.3
# 24                                      164.1
# 25                                      165.7
# 26                                      167.0
# 27                                      172.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Year                                       28 non-null     int64
#  1   Avg. cable bill                            28 non-null     float64
#  2   Median household income                    28 non-null     object
#  3   Social Security cost-of-living adjustment  28 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.0+ KB

# %%
df["Median household income"] = pd.to_numeric(df["Median household income"], errors = "coerce").copy()
df
# Out:
#     Year  Avg. cable bill  Median household income  \
# 0   1995            22.35                   35.249
# 1   1996            23.28                   36.689
# 2   1997            26.31                   38.229
# 3   1998            27.88                   40.148
# 4   1999            28.94                   41.994
# 5   2000            31.22                   42.349
# 6   2001            33.75                   42.710
# 7   2002            36.47                   43.057
# 8   2003            38.95                   43.564
# 9   2004            41.04                   44.684
# 10  2005            43.04                   46.242
# 11  2006            43.26                   48.451
# 12  2007            47.27                   50.740
# 13  2008            49.65                   52.029
# 14  2009            52.37                   50.221
# 15  2010            54.44                   50.046
# 16  2011            57.46                   50.502
# 17  2012            61.63                   51.371
# 18  2013            69.18                   52.250
# 19  2014            71.45                   53.657
# 20  2015            78.42                   55.775
# 21  2016           150.98                   57.617
# 22  2017           168.49                   61.372
# 23  2018           199.99                   64.324
# 24  2019           210.84                   69.560
# 25  2020           217.42                   67.521
# 26  2021           231.10                   70.784
# 27  2022           251.48                   78.075
#
#     Social Security cost-of-living adjustment
# 0                                       100.0
# 1                                       102.6
# 2                                       105.6
# 3                                       107.8
# 4                                       109.2
# 5                                       111.9
# 6                                       115.8
# 7                                       118.9
# 8                                       120.5
# 9                                       123.0
# 10                                      126.4
# 11                                      131.6
# 12                                      135.9
# 13                                      139.0
# 14                                      147.1
# 15                                      147.1
# 16                                      147.1
# 17                                      152.4
# 18                                      155.0
# 19                                      157.3
# 20                                      159.0
# 21                                      159.0
# 22                                      159.3
# 23                                      161.3
# 24                                      164.1
# 25                                      165.7
# 26                                      167.0
# 27                                      172.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Year                                       28 non-null     int64
#  1   Avg. cable bill                            28 non-null     float64
#  2   Median household income                    28 non-null     float64
#  3   Social Security cost-of-living adjustment  28 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 1.0 KB

# %%
df.plot(x="Year",
        y= ["Avg. cable bill", "Median household income", "Social Security cost-of-living adjustment"])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.plot(x = "Year",
       y = ["Avg. cable bill", "Median household income", "Social Security cost-of-living adjustment"],
       title = "Cable bill pricing over time")
# Out:
# <AxesSubplot:title={'center':'Cable bill pricing over time'}, xlabel='Year'>

# %%
df.plot(x = "Year",
       y = ["Avg. cable bill", "Median household income", "Social Security cost-of-living adjustment"],
       title = "Cable bill pricing over time",
       style = {"Avg. cable bill": "red",
               "Median household income": "blue",
               "Social Security cost-of-living adjustment": "gray"})
# Out:
# <AxesSubplot:title={'center':'Cable bill pricing over time'}, xlabel='Year'>

# %%
#### What would be your "thesis" based on your findings?
#From 2015 to 2022, the cost of cable bills in the United States has risen by 210 percent,
##while Median Household Income has only increased by almost 40 percent, and Social Security
##Income by just 13.9 percent. This means that the cost of cable bills has grown five times
##more than the average U.S. household income.
